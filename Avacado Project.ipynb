# %% [markdown]
# # Avacado Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# import our dataset
data = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv")
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# 3  2015.0  Albany
# 4  2015.0  Albany

# %%
data.tail()
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16463         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16464         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16465         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16466         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16467         NaN         NaN         NaN          NaN  NaN   NaN    NaN

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# Total Volume    0.967689    0.960642    0.910226     0.521717 -0.004189
# 4046            0.930395    0.922278    0.884229     0.474063 -0.040439
# 4225            0.951779    0.943988    0.900496     0.504718 -0.007254
# 4770            0.926405    0.923607    0.840523     0.646053  0.029222
# Total Bags      1.000000    0.997341    0.911336     0.601856  0.090108
# Small Bags      0.997341    1.000000    0.879131     0.611300  0.106382
# Large Bags      0.911336    0.879131    1.000000     0.447779 -0.018678
# XLarge Bags     0.601856    0.611300    0.447779     1.000000  0.218342
# year            0.090108    0.106382   -0.018678     0.218342  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# std    7.579765e+05  6.474765e+05  1.182157e+05    7455.712144     0.369324
# min    3.311770e+03  3.311770e+03  0.000000e+00       0.000000  2015.000000
# 25%    3.620689e+04  2.972722e+04  5.407400e+02       0.000000  2015.000000
# 50%    7.397906e+04  6.237569e+04  5.044350e+03       0.000000  2015.000000
# 75%    1.576097e+05  1.461994e+05  2.926767e+04     401.480000  2015.000000
# max    6.736304e+06  5.893642e+06  1.121076e+06  108072.790000  2016.000000

# %%
data.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
data.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.18, 1.29, 1.25, 1.03, 1.39,
#        1.4 , 1.36, 1.3 , 0.88, 1.21, 0.9 , 0.94, 0.75, 0.77, 0.81, 0.8 ,
#        0.72, 0.79, 0.67, 0.82, 0.68, 0.76, 0.91, 1.38, 0.92, 0.78, 0.74,
#        0.62, 0.83, 0.87, 0.73, 0.7 , 0.89, 0.85, 1.44, 1.42, 1.41, 0.49,
#        0.53, 0.66, 0.56, 0.6 , 0.71, 0.65, 0.58, 0.54, 0.52, 0.51, 0.57,
#        0.63, 0.64, 0.61, 0.84, 0.86, 0.69, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.51, 1.61, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.68,
#        1.54, 1.64, 1.58,  nan])

# %%
data.AveragePrice.value_counts()
# Out:
# 1.08    46
# 0.99    44
# 1.03    44
# 1.10    43
# 1.09    43
#         ..
# 1.58     1
# 0.49     1
# 1.50     1
# 1.54     1
# 0.54     1
# Name: AveragePrice, Length: 113, dtype: int64

# %%
a=data.AveragePrice.value_counts()

# %%
sns.distplot(a,bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %%
data.shape
# Out:
# (16468, 13)

# %%
data.size
# Out:
# 214084

# %%
data['AveragePrice'].mean()
# Out:
# 1.0749901120632825

# %%
data['Total Volume'].max()
# Out:
# 44655461.51

# %%
data['type'].value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
data[['Total Volume','Total Bags']].corr()
# Out:
#               Total Volume  Total Bags
# Total Volume      1.000000    0.967689
# Total Bags        0.967689    1.000000

# %%
sns.countplot(data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
data.nunique()
# Out:
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# type               1
# year               2
# region            51
# dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(data.type)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
plt.figure(figsize=(4,2))
sns.countplot(data.year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.barplot(x='year',y='Total Volume',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Total Volume'>

# %%
sns.barplot(x='year',y='AveragePrice',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
data.hist(edgecolor='red',linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>],
#        [<AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #removing outlier

# %%
data
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16463         NaN           NaN           NaN      NaN        NaN     NaN
# 16464         NaN           NaN           NaN      NaN        NaN     NaN
# 16465         NaN           NaN           NaN      NaN        NaN     NaN
# 16466         NaN           NaN           NaN      NaN        NaN     NaN
# 16467         NaN           NaN           NaN      NaN        NaN     NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1         9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2         8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3         5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4         6183.95     5986.26      197.69          0.0  conventional  2015.0
# ...           ...         ...         ...          ...           ...     ...
# 16463         NaN         NaN         NaN          NaN           NaN     NaN
# 16464         NaN         NaN         NaN          NaN           NaN     NaN
# 16465         NaN         NaN         NaN          NaN           NaN     NaN
# 16466         NaN         NaN         NaN          NaN           NaN     NaN
# 16467         NaN         NaN         NaN          NaN           NaN     NaN
#
#        region
# 0      Albany
# 1      Albany
# 2      Albany
# 3      Albany
# 4      Albany
# ...       ...
# 16463     NaN
# 16464     NaN
# 16465     NaN
# 16466     NaN
# 16467     NaN
#
# [16468 rows x 13 columns]

# %%
# dropping NA value 
df1 = data.dropna()
print(df1)
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015.0
# 1        9505.56     9408.07       97.49         0.00  conventional  2015.0
# 2        8145.35     8042.21      103.14         0.00  conventional  2015.0
# 3        5811.16     5677.40      133.76         0.00  conventional  2015.0
# 4        6183.95     5986.26      197.69         0.00  conventional  2015.0
# ...          ...         ...         ...          ...           ...     ...
# 1512    59418.46    48823.53    10354.65       240.28  conventional  2016.0
# 1513    63300.70    54704.14     8596.56         0.00  conventional  2016.0
# 1514    62415.77    53332.61     8258.16       825.00  conventional  2016.0
# 1515    63931.73    55653.47     8278.26         0.00  conventional  2016.0
# 1516    69104.56    57456.21    11648.35         0.00  conventional  2016.0
#
#          region
# 0        Albany
# 1        Albany
# 2        Albany
# 3        Albany
# 4        Albany
# ...         ...
# 1512  Charlotte
# 1513  Charlotte
# 1514  Charlotte
# 1515  Charlotte
# 1516  Charlotte
#
# [1517 rows x 13 columns]

# %%
df1
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015.0
# 1        9505.56     9408.07       97.49         0.00  conventional  2015.0
# 2        8145.35     8042.21      103.14         0.00  conventional  2015.0
# 3        5811.16     5677.40      133.76         0.00  conventional  2015.0
# 4        6183.95     5986.26      197.69         0.00  conventional  2015.0
# ...          ...         ...         ...          ...           ...     ...
# 1512    59418.46    48823.53    10354.65       240.28  conventional  2016.0
# 1513    63300.70    54704.14     8596.56         0.00  conventional  2016.0
# 1514    62415.77    53332.61     8258.16       825.00  conventional  2016.0
# 1515    63931.73    55653.47     8278.26         0.00  conventional  2016.0
# 1516    69104.56    57456.21    11648.35         0.00  conventional  2016.0
#
#          region
# 0        Albany
# 1        Albany
# 2        Albany
# 3        Albany
# 4        Albany
# ...         ...
# 1512  Charlotte
# 1513  Charlotte
# 1514  Charlotte
# 1515  Charlotte
# 1516  Charlotte
#
# [1517 rows x 13 columns]

# %%
df2=df1.drop(['type', 'region'], axis=1)

# %%
df2
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags    year
# 0        8696.87     8603.62       93.25         0.00  2015.0
# 1        9505.56     9408.07       97.49         0.00  2015.0
# 2        8145.35     8042.21      103.14         0.00  2015.0
# 3        5811.16     5677.40      133.76         0.00  2015.0
# 4        6183.95     5986.26      197.69         0.00  2015.0
# ...          ...         ...         ...          ...     ...
# 1512    59418.46    48823.53    10354.65       240.28  2016.0
# 1513    63300.70    54704.14     8596.56         0.00  2016.0
# 1514    62415.77    53332.61     8258.16       825.00  2016.0
# 1515    63931.73    55653.47     8278.26         0.00  2016.0
# 1516    69104.56    57456.21    11648.35         0.00  2016.0
#
# [1517 rows x 11 columns]

# %%
Q1=df2.quantile(0.25)
Q3=df2.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# AveragePrice         0.21
# Total Volume    834505.09
# 4046            357178.14
# 4225            443674.28
# 4770             28256.05
# Total Bags      121402.79
# Small Bags      116472.13
# Large Bags       28726.93
# XLarge Bags        401.48
# year                 0.00
# dtype: float64

# %%
new_df2=df2[~((df2<Q1-(1.5*IQR))|(df2>(Q3+(1.5*IQR)))).any(axis=1)]
new_df2
# Out:
#             Date  AveragePrice  Total Volume       4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62    1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98     674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22     794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15    1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60     941.48   43838.39     75.78
# ...          ...           ...           ...        ...        ...       ...
# 1265  01-02-2015          0.71     916367.42  611270.39  205181.23  14107.36
# 1266  25-01-2015          0.80     720800.61  519142.82  124248.86  10573.29
# 1267  18-01-2015          0.80     729795.72  516446.41  128438.87  12473.14
# 1268  11-01-2015          0.92     584896.99  347125.63  129717.42  27944.07
# 1269  04-01-2015          0.75     758118.95  426878.87  147958.43  15267.89
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags    year
# 0        8696.87     8603.62       93.25          0.0  2015.0
# 1        9505.56     9408.07       97.49          0.0  2015.0
# 2        8145.35     8042.21      103.14          0.0  2015.0
# 3        5811.16     5677.40      133.76          0.0  2015.0
# 4        6183.95     5986.26      197.69          0.0  2015.0
# ...          ...         ...         ...          ...     ...
# 1265    85808.44    82065.70     3742.74          0.0  2015.0
# 1266    66835.64    65072.69     1762.95          0.0  2015.0
# 1267    72437.30    71564.22      873.08          0.0  2015.0
# 1268    80109.87    78503.46     1606.41          0.0  2015.0
# 1269   168013.76   165202.22     2811.54          0.0  2015.0
#
# [881 rows x 11 columns]

# %%
data.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
data
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16463         NaN           NaN           NaN      NaN        NaN     NaN
# 16464         NaN           NaN           NaN      NaN        NaN     NaN
# 16465         NaN           NaN           NaN      NaN        NaN     NaN
# 16466         NaN           NaN           NaN      NaN        NaN     NaN
# 16467         NaN           NaN           NaN      NaN        NaN     NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1         9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2         8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3         5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4         6183.95     5986.26      197.69          0.0  conventional  2015.0
# ...           ...         ...         ...          ...           ...     ...
# 16463         NaN         NaN         NaN          NaN           NaN     NaN
# 16464         NaN         NaN         NaN          NaN           NaN     NaN
# 16465         NaN         NaN         NaN          NaN           NaN     NaN
# 16466         NaN         NaN         NaN          NaN           NaN     NaN
# 16467         NaN         NaN         NaN          NaN           NaN     NaN
#
#        region
# 0      Albany
# 1      Albany
# 2      Albany
# 3      Albany
# 4      Albany
# ...       ...
# 16463     NaN
# 16464     NaN
# 16465     NaN
# 16466     NaN
# 16467     NaN
#
# [16468 rows x 13 columns]

# %%
data['Year'], data['Month'], data['Day'] = data['Date'].str.split('-').str
data.drop(columns=['Date','year'], inplace=True)
data
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 16463           NaN           NaN      NaN        NaN     NaN         NaN
# 16464           NaN           NaN      NaN        NaN     NaN         NaN
# 16465           NaN           NaN      NaN        NaN     NaN         NaN
# 16466           NaN           NaN      NaN        NaN     NaN         NaN
# 16467           NaN           NaN      NaN        NaN     NaN         NaN
#
#        Small Bags  Large Bags  XLarge Bags          type  region Year Month  \
# 0         8603.62       93.25          0.0  conventional  Albany   27    12
# 1         9408.07       97.49          0.0  conventional  Albany   20    12
# 2         8042.21      103.14          0.0  conventional  Albany   13    12
# 3         5677.40      133.76          0.0  conventional  Albany   06    12
# 4         5986.26      197.69          0.0  conventional  Albany   29    11
# ...           ...         ...          ...           ...     ...  ...   ...
# 16463         NaN         NaN          NaN           NaN     NaN  NaN   NaN
# 16464         NaN         NaN          NaN           NaN     NaN  NaN   NaN
# 16465         NaN         NaN          NaN           NaN     NaN  NaN   NaN
# 16466         NaN         NaN          NaN           NaN     NaN  NaN   NaN
# 16467         NaN         NaN          NaN           NaN     NaN  NaN   NaN
#
#         Day
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
# ...     ...
# 16463   NaN
# 16464   NaN
# 16465   NaN
# 16466   NaN
# 16467   NaN
#
# [16468 rows x 14 columns]

# %%
## checking the correaltion of all column
data_cor = data.corr()
plt.figure(figsize=(30,25))
sns.heatmap(data_cor,annot=True)
plt.plot()
# Out:
# []
